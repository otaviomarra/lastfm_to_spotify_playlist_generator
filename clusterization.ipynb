# %%
from datetime import date, datetime

import numpy as np
import pandas as pd
from pandasql import sqldf
import plotly.express as px
import plotly.graph_objects as go
from sklearn.cluster import KMeans
from pandas_profiling import ProfileReport
from sklearn.preprocessing import MinMaxScaler

pysqldf = lambda q: sqldf(q, globals())

# %%
features = pd.read_csv('data/songs_features.csv')
played =  pd.read_csv('data/played_tracks.csv')
ids = pd.read_csv('data/tracks_ids.csv')

#hard fixing the column names for the played file
played.rename(columns={'0':'artist','1':'song_name','2':'unix_timestamp'}, inplace=True)

# %%
q = """
SELECT p.artist, p.song_name, p.unix_timestamp, f.*
FROM played as p
LEFT JOIN ids as i on i.band_name = p.artist and i.song_name = p.song_name
LEFT JOIN features as f on f.id = i.sp_id
"""
raw = pysqldf(q)

# %% [markdown]
# #### Organize the dataset

# %%
#take a look at the NaNs first to be sure 
raw[raw['id'].isna() == False][['artist', 'song_name']].nunique()
#there are 1051 unique songs we couldn't find the id (17.4%)
##I'll find a way to deal with this another time
# Out:
# artist       1525
# song_name    4988
# dtype: int64

# %%
#unix timestamp to readable datetime
raw['play_timestamp'] = pd.to_datetime(raw['unix_timestamp'], unit='s')
#remove the tracks we could not find the spotify id
raw.dropna(inplace= True )
#drop some columns we won't need (or that I don't want to use as a feature)
raw.drop(columns = ['unix_timestamp', 'key', 'mode', 'speechiness', 'liveness', 'type', 'uri', 'track_href', 'analysis_url'], axis = 1, inplace  =True)

# %% [markdown]
# Pandas profiling all the song features

# %%
profile = ProfileReport(
    raw[['danceability', 'energy', 'loudness','acousticness', 'instrumentalness', 'valence', 'tempo', 'duration_ms','time_signature']], 
    title='Song features 2019',
    html={'style':{'full_width':True}})
profile.to_file('profiling.html')
# Out:
# Summarize dataset: 100%|██████████| 24/24 [00:15<00:00,  1.55it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:05<00:00,  5.20s/it]
# Render HTML: 100%|██████████| 1/1 [00:02<00:00,  2.56s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 64.63it/s]

# %% [markdown]
# ## K-means

# %%
raw.groupby('id').count().describe()['play_timestamp']

# %%
# Cleaning up a bit more so we can generate playlists only with songs oftenr listened to
##I'd like to check the results considering only the songs that I've listened to more than once
q = """
with base as(
    SELECT DISTINCT id,
        danceability,
        energy,
        loudness,
        acousticness,
        instrumentalness,
        valence,
        tempo,
        COUNT(*) as count
    FROM raw
    GROUP BY 1,2,3,4,5,6,7,8)
SELECT * FROM base --WHERE count > 1
"""
kdf = pysqldf(q)

# %%
#Visualizing all features distributions on scatterplots
fig = px.scatter_matrix(kdf.drop(columns = ["id", "count"],axis=1),
width=1200, height=1600)
fig.show()

# %%
#Defining how many clusters would fit best for our data

X=kdf.drop(columns = ["id", "count"],axis=1)

#using StandardScaler to normalize allv alues between 0 and 1
scaler = MinMaxScaler()
scaler.fit(X)
X=scaler.transform(X)

#get the inertial value for 1-10 clusters
inertia = []
for i in range(1,11):
    kmeans = KMeans(
        n_clusters=i, init="k-means++",
        n_init=10,
        tol=1e-04, random_state=4
    )
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)
#plot the chart so we can find the elbolw
fig = go.Figure(data=go.Scatter(x=np.arange(1,11),y=inertia))
fig.update_layout(title="Inertia vs Cluster Number",xaxis=dict(range=[0,11],title="Cluster Number"),
                  yaxis={'title':'Inertia'},
                 annotations=[
        dict(
            x=3,
            y=inertia[2],
            xref="x",
            yref="y",
            text="Elbow test for k-means",
            showarrow=True,
            arrowhead=7,
            ax=20,
            ay=-60
        )
    ])

# %%
#implementing the k-means model
#I decided to go with 4. Whatever
kmeans = KMeans(
        n_clusters=4, 
        init="k-means++",
        n_init=10,
        max_iter=1000,
        tol=1e-04, 
        random_state=4)
kmeans.fit(X) #X from the above cell
# Out:
# KMeans(max_iter=1000, n_clusters=4, random_state=4)

# %%
clusters=pd.DataFrame(X,columns=kdf.drop(columns=["id", 'count'],axis=1).columns)
clusters['label']=kmeans.labels_
polar=clusters.groupby("label").mean().reset_index()
polar=pd.melt(polar,id_vars=["label"])
fig = px.line_polar(polar, r="value", theta="variable", color="label", line_close=True, height=800,width=1400)
fig.show()

# %%
clusters['id'] = kdf['id']
clusters.groupby('label').count()['id']
# Out:
# label
# 0    2237
# 1    1279
# 2     550
# 3     987
# Name: id, dtype: int64

# %% [markdown]
# ### Taking a look at the clusters generated

# %%
q = """
SELECT DISTINCT c.label, p.artist, p.song_name
FROM played as p
LEFT JOIN ids as i on i.band_name = p.artist and i.song_name = p.song_name
LEFT JOIN clusters as c on c.id = i.sp_id
"""
tempdf = pysqldf(q)
for i in range(len(clusters['label'].unique())):
    print("Cluster ",clusters['label'].unique()[i].item())
    tempdf2 = tempdf[tempdf['label'] == clusters['label'].unique()[i].item()] 
    print(tempdf2.sample(25))
    print("\n")
# Out:
# Cluster  0
#       label         artist                              song_name
# 4695    0.0     Axel Boman                     Paid By The Rhythm
# 4060    0.0      Ø [Phase]                               200301.2
# 2255    0.0          Sleep                            Sonic Titan
# 5584    0.0    New Jackson                         the night mail
# 3351    0.0    Snowy Dunes                 Tranquil Mountain Lake
# 5435    0.0        Shifted                            For Closure
# 3150    0.0      Trap Them                    Stray Of The Tongue
# 3176    0.0      Trap Them  Malengines Here, Where They Should Be
# 28      0.0     Hot Snakes                         Candid Cameras
# 489     0.0   Acruz Sesper                        Invisible Lines
# 3287    0.0           Zeke                              Chinatown
# 2924    0.0           Rone                                    Lou
# 2305    0.0    Joy Orbison                             Off Season
# 4888    0.0  Chris Liebing                                  Tunox
# 1702    0.0   Joy Division              Candidate - 2007 Remaster
# 3221    0.0         Ansome              Blackwater - Ossian Remix
# 257     0.0         Kölsch                                  Serij
# 1379    0.0    Beach House                              Black Car
# 1907    0.0      Ben Klock                   Cargo - Original Mix
# 3820    0.0         Blawan                        Many Many Pings
# 1478    0.0           Slam                              Astrolabe
# 2304    0.0    Joy Orbison                                 Fuerza
# 3388    0.0      Ø [Phase]                               Orbitron
# 6108    0.0        Tzusing                     Digital Properties
# 4026    0.0       La Fleur                                  Tears
#
#
# Cluster  1
#       label                       artist              song_name
# 2486    1.0                 Birds in Row                  15-38
# 3629    1.0                      Justice                   Ohio
# 2147    1.0                  Japandroids  Adrenaline Nightshift
# 6098    1.0                     Function                     Be
# 1960    1.0      Queens of the Stone Age            Misfit Love
# 487     1.0                     Baroness               Kerosene
# 4850    1.0                         Blur          Country House
# 902     1.0                    Boogarins              Avalanche
# 4295    1.0                 Joey Beltram             Flash Cube
# 2463    1.0              Ancient Methods     The House Of Rahab
# 4235    1.0                  Iron Reagan             I Won't Go
# 4963    1.0                        Boris    Woman on the Screen
# 1950    1.0             The Hellacopters        Better Than You
# 1510    1.0       The Murder City Devils             Idle Hands
# 1623    1.0             The Hellacopters  Truckloads of Nothin'
# 5576    1.0                   Black Flag             Slip It In
# 4863    1.0                     1000mods         Dear Herculine
# 4530    1.0                       Slayer           Human Strain
# 3658    1.0                  Iron Reagan      Miserable Failure
# 5669    1.0                     Baptists              String Up
# 1745    1.0  Black Rebel Motorcycle Club     As Sure as the Sun
# 3817    1.0                    Gluecifer          Desolate City
# 2627    1.0                  Narrow Head     Stuttering Stanley
# 2365    1.0                  The Orwells       Always n Forever
# 2098    1.0                       SBTRKT                 Higher
#
#
# Cluster  2
#       label                      artist  \
# 346     2.0                  True Widow
# 3462    2.0                 Oathbreaker
# 441     2.0                 James Blake
# 2916    2.0                       Plaid
# 2931    2.0                     Apparat
# 242     2.0                 Colour Haze
# 2689    2.0                   Ben Klock
# 334     2.0           Philipp Gorbachev
# 252     2.0                 Miles Davis
# 6113    2.0                   Stan Getz
# 5636    2.0                    Slowdive
# 5658    2.0                  Luiz Bonfá
# 4403    2.0                 Yellow Days
# 364     2.0              Charles Mingus
# 3275    2.0                     Archive
# 5067    2.0               Glass Animals
# 2670    2.0                  Brainstory
# 343     2.0                  True Widow
# 4040    2.0               John Coltrane
# 2748    2.0  LSD and the Search for God
# 3885    2.0                       Sleep
# 196     2.0                   Kraftwerk
# 5247    2.0                    Four Tet
# 4471    2.0                     Kiasmos
# 1568    2.0                  Acid Pauli
#
#                                    song_name
# 346                                For Grace
# 3462                Stay Here / Accroche-Moi
# 441                                 Godspeed
# 2916                               Do Matter
# 2931                                 Knowing
# 242                                 Mountain
# 2689                 Init One - Original Mix
# 334                               The Virgin
# 252                          'Round Midnight
# 6113                               Sambalero
# 5636                            Melon Yellow
# 5658                                Shearing
# 4403                      Love Is Everywhere
# 364                                    Canon
# 3275  Again - Version - Band Of Skulls Remix
# 5067                        Heart-Shaped Box
# 2670                               Thank You
# 343                                   S.Y.B.
# 4040                         Russian Lullaby
# 2748                           Starting Over
# 3885                              Some Grass
# 196                 Prologue - 2009 Remaster
# 5247                   Mama Teaches Sanskrit
# 4471                                  Paused
# 1568                      Du Brecht, Ich Dub
#
#
# Cluster  3
#       label                                artist  \
# 2681    3.0                        Parquet Courts
# 557     3.0  Grandmaster Flash & The Furious Five
# 2242    3.0       The Jon Spencer Blues Explosion
# 528     3.0                           Tame Impala
# 5680    3.0                            King Krule
# 3452    3.0                               M. Ward
# 2375    3.0                             The Drums
# 772     3.0               Queens of the Stone Age
# 5457    3.0                                 Flume
# 4046    3.0                       Franz Ferdinand
# 2357    3.0                        Parquet Courts
# 4348    3.0                                 HÆLOS
# 31      3.0                             Moss Icon
# 3951    3.0                                Woolfy
# 79      3.0                           Fleet Foxes
# 1954    3.0                         Primal Scream
# 1378    3.0                             Kurt Vile
# 3634    3.0                  Two Door Cinema Club
# 762     3.0               Queens of the Stone Age
# 3245    3.0                          Joe Strummer
# 540     3.0                         Evelyn Thomas
# 3920    3.0                              Breakbot
# 4360    3.0                             Sevdaliza
# 1220    3.0                          Led Zeppelin
# 5297    3.0                             Terno Rei
#
#                                      song_name
# 2681                      What Color Is Blood?
# 557   White Lines (Long Version) [Re-Recorded]
# 2242                   Right Place, Wrong Time
# 528                             Breathe Deeper
# 5680                                Comet Face
# 3452               Daydream (feat. Alia Farah)
# 2375                                     Money
# 772                         I Sat by the Ocean
# 5457                            The Difference
# 4046                              Come On Home
# 2357                         Human Performance
# 4348                                     Kyoto
# 31                                      Locket
# 3951                               City Lights
# 79                                  Maestranza
# 1954                   Where the Light Gets In
# 1378                             Pretty Pimpin
# 3634                                   Tiptoes
# 762                                 Auto Pilot
# 3245                                 Coma Girl
# 540                                High Energy
# 3920                                translight
# 4360                              Human Nature
# 1220          When the Levee Breaks - Remaster
# 5297                                 São Paulo

# %%
clusters.to_csv('data/clusterization.csv', index=False)
